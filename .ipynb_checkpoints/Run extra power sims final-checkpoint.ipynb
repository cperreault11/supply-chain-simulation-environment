# %%
from scse.main import miniSCOTnotebook
import numpy as np
import pandas as pd
import sys
# Out:
# DEBUG:scse.profiles.profile:Open profile file = /home/cperreault/scse1/lib/python3.7/site-packages/scse/profiles/power_supply.json.
# DEBUG:scse.profiles.profile:module_name is scse.metrics.power_contract_profit
# DEBUG:scse.profiles.profile:module_name is scse.modules.production.renewables_firm
# DEBUG:matplotlib:matplotlib data path: /home/cperreault/scse1/lib/python3.7/site-packages/matplotlib/mpl-data
# DEBUG:matplotlib:CONFIGDIR=/home/cperreault/.config/matplotlib
# DEBUG:matplotlib:interactive is False
# DEBUG:matplotlib:platform is linux
# DEBUG:matplotlib:loaded modules: ['sys', 'builtins', '_frozen_importlib', '_imp', '_thread', '_warnings', '_weakref', 'zipimport', '_frozen_importlib_external', '_io', 'marshal', 'posix', 'encodings', 'codecs', '_codecs', 'encodings.aliases', 'encodings.utf_8', '_signal', '__main__', 'encodings.latin_1', 'io', 'abc', '_abc', '_bootlocale', '_locale', 'site', 'os', 'stat', '_stat', '_collections_abc', 'posixpath', 'genericpath', 'os.path', '_sitebuiltins', '_virtualenv', 'importlib', 'importlib._bootstrap', 'importlib._bootstrap_external', 'types', 'warnings', 'importlib.abc', 'importlib.machinery', 'importlib.util', 'contextlib', 'collections', 'operator', '_operator', 'keyword', 'heapq', '_heapq', 'itertools', 'reprlib', '_collections', 'functools', '_functools', 'threading', 'time', 'traceback', 'linecache', 'tokenize', 're', 'enum', 'sre_compile', '_sre', 'sre_parse', 'sre_constants', 'copyreg', 'token', '_weakrefset', 'mpl_toolkits', 'sitecustomize', 'runpy', 'pkgutil', 'weakref', 'ipykernel', 'ipykernel._version', 'ipykernel.connect', 'json', 'json.decoder', 'json.scanner', '_json', 'json.encoder', 'subprocess', 'signal', 'errno', '_posixsubprocess', 'select', 'selectors', 'collections.abc', 'math', 'jupyter_client', 'jupyter_client._version', 'typing', 'typing.io', 'typing.re', 'jupyter_client.asynchronous', 'jupyter_client.asynchronous.client', 'traitlets', 'traitlets.traitlets', 'ast', '_ast', 'inspect', 'dis', 'opcode', '_opcode', 'traitlets.utils', 'traitlets.utils.getargspec', 'traitlets.utils.importstring', 'traitlets.utils.sentinel', 'traitlets.utils.bunch', 'traitlets.utils.descriptions', 'traitlets.utils.decorators', 'copy', 'traitlets._version', 'jupyter_client.channels', 'asyncio', 'asyncio.base_events', 'concurrent', 'concurrent.futures', 'concurrent.futures._base', 'logging', 'string', '_string', 'atexit', 'socket', '_socket', 'ssl', '_ssl', 'base64', 'struct', '_struct', 'binascii', 'asyncio.constants', 'asyncio.coroutines', 'asyncio.base_futures', 'asyncio.format_helpers', 'asyncio.log', 'asyncio.events', 'contextvars', '_contextvars', 'asyncio.base_tasks', '_asyncio', 'asyncio.futures', 'asyncio.protocols', 'asyncio.sslproto', 'asyncio.transports', 'asyncio.tasks', 'asyncio.locks', 'asyncio.runners', 'asyncio.queues', 'asyncio.streams', 'asyncio.subprocess', 'asyncio.unix_events', 'asyncio.base_subprocess', 'asyncio.selector_events', 'queue', '_queue', 'zmq', 'platform', 'ctypes', '_ctypes', 'ctypes._endian', 'zmq.backend', 'zmq.backend.select', 'zmq.backend.cython', 'zmq.backend.cython.constants', 'cython_runtime', 'zmq.backend.cython.error', '_cython_0_29_24', 'zmq.backend.cython.message', 'zmq.error', 'zmq.backend.cython.context', 'zmq.backend.cython.socket', 'random', 'hashlib', '_hashlib', '_blake2', '_sha3', 'bisect', '_bisect', '_random', 'pickle', '_compat_pickle', '_pickle', 'zmq.backend.cython.utils', 'zmq.backend.cython._poll', 'zmq.backend.cython._version', 'zmq.backend.cython._device', 'zmq.backend.cython._proxy_steerable', 'zmq.sugar', 'zmq.sugar.constants', 'zmq.utils', 'zmq.utils.constant_names', 'zmq.sugar.context', 'zmq.sugar.attrsettr', 'zmq.sugar.socket', 'zmq.sugar.poll', 'zmq.utils.jsonapi', 'zmq.utils.strtypes', 'zmq.sugar.frame', 'zmq.sugar.tracker', 'zmq.sugar.version', 'zmq.sugar.stopwatch', 'zmq.asyncio', 'zmq._future', 'jupyter_client.channelsabc', 'jupyter_client.session', 'hmac', 'pprint', 'datetime', '_datetime', 'traitlets.config', 'traitlets.config.application', 'traitlets.config.configurable', 'traitlets.config.loader', 'argparse', 'gettext', 'locale', 'traitlets.utils.text', 'textwrap', 'traitlets.log', 'zmq.eventloop', 'zmq.eventloop.ioloop', '__future__', 'tornado', 'tornado.log', 'logging.handlers', 'tornado.escape', 'html', 'html.entities', 'urllib', 'urllib.parse', 'tornado.util', 'array', 'zlib', 'tornado.speedups', 'curses', '_curses', 'tornado.ioloop', 'numbers', 'tornado.concurrent', 'tornado.platform', 'tornado.platform.asyncio', 'tornado.gen', 'zmq.eventloop.z ...
# DEBUG:matplotlib:CACHEDIR=/home/cperreault/.cache/matplotlib
# DEBUG:matplotlib.font_manager:Using fontManager instance from /home/cperreault/.cache/matplotlib/fontlist-v330.json
# DEBUG:matplotlib.pyplot:Loaded backend module://matplotlib_inline.backend_inline version unknown.
# DEBUG:matplotlib.pyplot:Loaded backend module://matplotlib_inline.backend_inline version unknown.
# DEBUG:scse.profiles.profile:module_name is scse.modules.production.cheap_ramp_firm
# DEBUG:scse.profiles.profile:module_name is scse.modules.production.expensive_ramp_firm
# DEBUG:scse.profiles.profile:module_name is scse.modules.demand.power_demand
# INFO:GP:initializing Y
# INFO:GP:initializing inference method
# INFO:GP:adding kernel and likelihood as parameters
# DEBUG:scse.controller.miniscot:Resetting Agent: renewables_firm.
# DEBUG:scse.controller.miniscot:Resetting Agent: cheap_ramp_firm.
# DEBUG:scse.controller.miniscot:Resetting Agent: expensive_ramp_firm.
# DEBUG:scse.controller.miniscot:Resetting Agent: demand_generator.
# DEBUG:scse.controller.miniscot:trying to reset signed-in services

# %%
m = miniSCOTnotebook()
# Out:
# DEBUG:scse.profiles.profile:Open profile file = /home/cperreault/scse1/lib/python3.7/site-packages/scse/profiles/power_supply.json.
# DEBUG:scse.profiles.profile:module_name is scse.metrics.power_contract_profit
# DEBUG:scse.profiles.profile:module_name is scse.modules.production.renewables_firm
# DEBUG:scse.profiles.profile:module_name is scse.modules.production.cheap_ramp_firm
# DEBUG:scse.profiles.profile:module_name is scse.modules.production.expensive_ramp_firm
# DEBUG:scse.profiles.profile:module_name is scse.modules.demand.power_demand
# INFO:GP:initializing Y
# INFO:GP:initializing inference method
# INFO:GP:adding kernel and likelihood as parameters
# DEBUG:scse.controller.miniscot:Resetting Agent: renewables_firm.
# DEBUG:scse.controller.miniscot:Resetting Agent: cheap_ramp_firm.
# DEBUG:scse.controller.miniscot:Resetting Agent: expensive_ramp_firm.
# DEBUG:scse.controller.miniscot:Resetting Agent: demand_generator.
# DEBUG:scse.controller.miniscot:trying to reset signed-in services

# %%
run_params={
    'time_horizon':730,
    'extra_power': 2,
    #'flexible_capacity': 2500000,
    'static_capacity': 5500000,
    'renewable_scale': 2500000,
}

# %%
flexible_scales = np.linspace(.1,.7,13)

# %%
flexible_scales = [round(x,2) for x in flexible_scales]

# %%
num_runs = 10
path = "./sims/flexible_scales/"
market_demand = 7000000

# %%
for s in flexible_scales:
    for i in range(num_runs):
        sys.stdout = open(path + "flexible_{}_{}".format(s,i),'w')
        run_params['flexible_capacity'] = market_demand * s
        m.start(**run_params)
        m.run()
# Out:
# DEBUG:scse.profiles.profile:Open profile file = /home/cperreault/scse1/lib/python3.7/site-packages/scse/profiles/power_supply.json.
# DEBUG:scse.profiles.profile:module_name is scse.metrics.power_contract_profit
# DEBUG:scse.profiles.profile:module_name is scse.modules.production.renewables_firm
# DEBUG:scse.profiles.profile:module_name is scse.modules.production.cheap_ramp_firm
# DEBUG:scse.profiles.profile:module_name is scse.modules.production.expensive_ramp_firm
# DEBUG:scse.profiles.profile:module_name is scse.modules.demand.power_demand
# INFO:GP:initializing Y
# INFO:GP:initializing inference method
# INFO:GP:adding kernel and likelihood as parameters
# DEBUG:scse.controller.miniscot:Resetting Agent: renewables_firm.
# DEBUG:scse.controller.miniscot:Resetting Agent: cheap_ramp_firm.
# DEBUG:scse.controller.miniscot:Resetting Agent: expensive_ramp_firm.
# DEBUG:scse.controller.miniscot:Resetting Agent: demand_generator.
# DEBUG:scse.controller.miniscot:trying to reset signed-in services
# DEBUG:scse.controller.miniscot:Getting actions from Agent: renewables_firm.
# DEBUG:scse.modules.production.renewables_firm:renewables_firm produced 1992330.943634311 MW, sd 457347.3569012189
# DEBUG:scse.controller.miniscot:Getting actions from Agent: cheap_ramp_firm.
# DEBUG:scse.controller.miniscot:Getting actions from Agent: expensive_ramp_firm.
# DEBUG:scse.controller.miniscot:Getting actions from Agent: demand_generator.
# DEBUG:scse.controller.miniscot:clock: 1
# INFO:scse.controller.miniscot:timestep is = 1
# INFO:scse.controller.miniscot:datetime is = 2019-01-02 00:00:00
# INFO:scse.controller.miniscot:Timestep Reward = 640428736.5737782
# INFO:scse.controller.miniscot:Episode Reward = 640428736.5737782
# DEBUG:scse.controller.miniscot:Getting actions from Agent: renewables_firm.
# DEBUG:scse.modules.production.renewables_firm:renewables_firm produced 1180385.8817156532 MW, sd 458705.68775599217
# DEBUG:scse.controller.miniscot:Getting actions from Agent: cheap_ramp_firm.
# DEBUG:scse.controller.miniscot:Getting actions from Agent: expensive_ramp_firm.
# DEBUG:scse.controller.miniscot:Getting actions from Agent: demand_generator.
# DEBUG:scse.controller.miniscot:clock: 2
# INFO:scse.controller.miniscot:timestep is = 2
# INFO:scse.controller.miniscot:datetime is = 2019-01-03 00:00:00
# INFO:scse.controller.miniscot:Timestep Reward = 700215435.2686261
# INFO:scse.controller.miniscot:Episode Reward = 1340644171.8424044
# DEBUG:scse.controller.miniscot:Getting actions from Agent: renewables_firm.
# DEBUG:scse.modules.production.renewables_firm:renewables_firm produced 2023420.6037492966 MW, sd 458597.68267169764
# DEBUG:scse.controller.miniscot:Getting actions from Agent: cheap_ramp_firm.
# DEBUG:scse.controller.miniscot:Getting actions from Agent: expensive_ramp_firm.
# DEBUG:scse.controller.miniscot:Getting actions from Agent: demand_generator.
# DEBUG:scse.controller.miniscot:clock: 3
# INFO:scse.controller.miniscot:timestep is = 3
# INFO:scse.controller.miniscot:datetime is = 2019-01-04 00:00:00
# INFO:scse.controller.miniscot:Timestep Reward = 671939426.2667687
# INFO:scse.controller.miniscot:Episode Reward = 2012583598.109173
# DEBUG:scse.controller.miniscot:Getting actions from Agent: renewables_firm.
# DEBUG:scse.modules.production.renewables_firm:renewables_firm produced 1263093.7404162881 MW, sd 459622.18107592635
# DEBUG:scse.controller.miniscot:Getting actions from Agent: cheap_ramp_firm.
# DEBUG:scse.controller.miniscot:Getting actions from Agent: expensive_ramp_firm.
# DEBUG:scse.controller.miniscot:Getting actions from Agent: demand_generator.
# DEBUG:scse.controller.miniscot:clock: 4
# INFO:scse.controller.miniscot:timestep is = 4
# INFO:scse.controller.miniscot:datetime is = 2019-01-05 00:00:00
# INFO:scse.controller.miniscot:Timestep Reward = 703523749.6166515
# INFO:scse.controller.miniscot:Episode Reward = 2716107347.7258244
# DEBUG:scse.controller.miniscot:Getting actions from Agent: renewables_firm.
# DEBUG:scse.modules.production.renewables_firm:renewables_firm produced 1195303.9443864815 MW, sd 457274.8629824257
# DEBUG:scse.controller.miniscot:Getting actions from Agent: cheap_ramp_firm.
# DEBUG:scse.controller.miniscot:Getting actions from Agent: expensive_ramp_firm.
# DEBUG:scse.controller.miniscot:Getting actions from Agent: demand_generator.
# DEBUG:scse.controller.miniscot:clock: 5
# INFO:scse.controller.miniscot:timestep is = 5
# INFO:scse.controller.miniscot:datetime is = 2019-01-06 00:00:00
# INFO:scse.controller.miniscot:Timestep Reward = 700812157.7754593
# INFO:scse.controller.miniscot:Episode Reward = 3416919505.5012836
# DEBUG:scse.controller.miniscot:Getting actions from Agent: renewables_firm.
# DEBUG:scse.modules.production.renewables_firm:renewables_firm produced 1040550.9066659845 MW, sd 458060.49782001507
# DEBUG:scse.controller.miniscot:Getting actions from Agent: cheap_ramp_firm.
# DEBUG:scse.controller.miniscot:Getting actions from Agent: expensive_ramp_firm.
# DEBUG:scse.controller.miniscot:Getting actions from Agent: demand_generator.
# DEBUG:scse.controller.miniscot:clock: 6
# INFO:scse.controller.miniscot:timestep is = 6
# INFO:scse.controller.miniscot:datetime is = 2019-01-07 00:00:00
# INFO:scse.controller.miniscot:Timestep Reward = 694622036.2666394
# INFO:scse.controller.miniscot:Episode Reward = 4111541541.767923
# DEBUG:scse.controller.miniscot:Getting actions from Agent: renewables_firm.
# DEBUG:scse.modules.production.renewables_firm:renewables_firm produced 1745298.7793288673 MW, sd 457749.90215889167
# DEBUG:scse.controller.miniscot:Getting actions from Agent: cheap_ramp_firm.
# DEBUG:scse.controller.miniscot:Getting actions from Agent: expensive_ramp_firm.
# DEBUG:scse.controller.miniscot:Getting actions from Agent: demand_generator.
# DEBUG:scse.controller.miniscot:clock: 7
# INFO:scse.controller.miniscot:timestep is = 7
# INFO:scse.controller.miniscot:datetime is = 2019-01-08 00:00:00
# INFO:scse.controller.miniscot:Timestep Reward = 722811951.1731547
# INFO:scse.controller.miniscot:Episode Reward = 4834353492.941077
# DEBUG:scse.controller.miniscot:Getting actions from Agent: renewables_firm.
# DEBUG:scse.modules.production.renewables_firm:renewables_firm produced 2279299.721712682 MW, sd 457263.4366573514
# DEBUG:scse.controller.miniscot:Getting actions from Agent: cheap_ramp_firm.
# DEBUG:scse.controller.miniscot:Getting actions from Agent: expensive_ramp_firm.
# DEBUG:scse.controller.miniscot:Getting actions from Agent: demand_generator.
# DEBUG:scse.controller.miniscot:clock: 8
# INFO:scse.controller.miniscot:timestep is = 8
# INFO:scse.controller.miniscot:datetime is = 2019-01-09 00:00:00
# INFO:scse.controller.miniscot:Timestep Reward = 730244672.5561773
# INFO:scse.controller.miniscot:Episode Reward = 5564598165.497254
# DEBUG:scse.controller.miniscot:Getting actions from Agent: renewables_firm.
# DEBUG:scse.modules.production.renewables_firm:renewables_firm produced 1800760.9788285901 MW, sd 459537.05705498345
# DEBUG:scse.controller.miniscot:Getting actions from Agent: cheap_ramp_firm.
# DEBUG:scse.controller.miniscot:Getting actions from Agent: expensive_ramp_firm.
# DEBUG:scse.controller.miniscot:Getting actions from Agent: demand_generator.
# DEBUG:scse.controller.miniscot:clock: 9
# INFO:scse.controller.miniscot:timestep is = 9
# INFO:scse.controller.miniscot:datetime is = 2019-01-10 00:00:00
# INFO:scse.controller.miniscot:Timestep Reward = 725030439.1531436
# INFO:scse.controller.miniscot:Episode Reward = 6289628604.650398
# DEBUG:scse.controller.miniscot:Getting actions from Agent: renewables_firm.
# DEBUG:scse.modules.production.renewables_firm:renewables_firm produced 1638573.563189202 MW, sd 459602.51857227506
# DEBUG:scse.controller.miniscot:Getting actions from Agent: cheap_ramp_firm.
# DEBUG:scse.controller.miniscot:Getting actions from Agent: expensive_ramp_firm.
# DEBUG:scse.controller.miniscot:Getting actions from Agent: demand_generator.
# DEBUG:scse.controller.miniscot:clock: 10
# INFO:scse.controller.miniscot:timestep is = 10
# INFO:scse.controller.miniscot:datetime is = 2019-01-11 00:00:00
# INFO:scse.controller.miniscot:Timestep Reward = 718542942.5275681
# INFO:scse.controller.miniscot:Episode Reward = 7008171547.177966
# DEBUG:scse.controller.miniscot:Getting actions from Agent: renewables_firm.
# DEBUG:scse.modules.production.renewables_firm:renewables_firm produced 1582199.3162606475 MW, sd 458866.67299992114
# DEBUG:scse.controller.miniscot:Getting actions from Agent: cheap_ramp_firm.
# DEBUG:scse.controller.miniscot:Getting actions from Agent: expensive_ramp_firm.
# DEBUG:scse.controller.miniscot:Getting actions from Agent: demand_generator.
# DEBUG:scse.controller.miniscot:clock: 11
# INFO:scse.controller.miniscot:timestep is = 11
# INFO:scse.controller.miniscot:datetime is = 2019-01-12 00:00:00
# INFO:scse.controller.miniscot:Timestep Reward = 716287972.6504259
# INFO:scse.controller.miniscot:Episode Reward = 7724459519.828392
# DEBUG:scse.controller.miniscot:Getting actions from Agent: renewables_firm.
# DEBUG:scse.modules.production.renewables_firm:renewables_firm produced 2285210.064766624 MW, sd 457256.39455176686
# DEBUG:scse.controller.miniscot:Getting actions from Agent: cheap_ramp_firm.
# DEBUG:scse.controller.miniscot:Getting actions from Agent: expensive_ramp_firm.
# DEBUG:scse.controller.miniscot:Getting actions from Agent: demand_generator.
# DEBUG:scse.controller.miniscot:clock: 12
# INFO:scse.controller.miniscot:timestep is = 12
# INFO:scse.controller.miniscot:datetime is = 2019-01-13 00:00:00
# INFO:scse.controller.miniscot:Timestep Reward = 688392735.7654878
# INFO:scse.controller.miniscot:Episode Reward = 8412852255.59388
# DEBUG:scse.controller.miniscot:Getting actions from Agent: renewables_firm.
# DEBUG:scse.modules.production.renewables_firm:renewables_firm produced 2273668.437925458 MW, sd 458576.63461010746
# DEBUG:scse.controller.miniscot:Getting actions from Agent: cheap_ramp_firm.
# DEBUG:scse.controller.miniscot:Getting actions from Agent: expensive_ramp_firm.
# DEBUG:scse.controller.miniscot:Getting actions from Agent: demand_generator.
# DEBUG:scse.controller.miniscot:clock: 13
# INFO:scse.controller.miniscot:timestep is = 13
# INFO:scse.controller.miniscot:datetime is = 2019-01-14 00:00:00
# INFO:scse.controller.miniscot:Timestep Reward = 661117769.5100095
# INFO:scse.controller.miniscot:Episode Reward = 9073970025.10389
# DEBUG:scse.controller.miniscot:Getting actions from Agent: renewables_firm.
# DEBUG:scse.modules.production.renewables_firm:renewables_firm produced 1984662.2714441563 MW, sd 459675.9110873975
# DEBUG:scse.controller.miniscot:Getting actions from Agent: cheap_ramp_firm.
# DEBUG:scse.controller.miniscot:Getting actions from Agent: expensive_ramp_firm.
# DEBUG:scse.controller.miniscot:Getting actions from Agent: demand_generator.
# DEBUG:scse.controller.miniscot:clock: 14
# INFO:scse.controller.miniscot:timestep is = 14
# INFO:scse.controller.miniscot:datetime is = 2019-01-15 00:00:00
# INFO:scse.controller.miniscot:Timestep Reward = 732386490.8577663
# INFO:scse.controller.miniscot:Episode Reward = 9806356515.961657
# DEBUG:scse.controller.miniscot:Getting actions from Agent: renewables_firm.
# DEBUG:scse.modules.production.renewables_firm:renewables_firm produced 1770647.3900524632 MW, sd 457208.41528397356
# DEBUG:scse.controller.miniscot:Getting actions from Agent: cheap_ramp_firm.
# DEBUG:scse.controller.miniscot:Getting actions from Agent: expensive_ramp_firm.
# DEBUG:scse.controller.miniscot:Getting actions from Agent: demand_generator.
# DEBUG:scse.controller.miniscot:clock: 15
# INFO:scse.controller.miniscot:timestep is = 15
# INFO:scse.controller.miniscot:datetime is = 2019-01-16 00:00:00
# INFO:scse.controller.miniscot:Timestep Reward = 723825895.6020985
# INFO:scse.controller.miniscot:Episode Reward = 10530182411.563755
# DEBUG:scse.controller.miniscot:Getting actions from Agent: renewables_firm.
# DEBUG:scse.modules.production.renewables_firm:renewables_firm produced 1195151.0727151497 MW, sd 458480.0788444737
# DEBUG:scse.controller.miniscot:Getting actions from Agent: cheap_ramp_firm.
# DEBUG:scse.controller.miniscot:Getting actions from Agent: expensive_ramp_firm.
# DEBUG:scse.controller.miniscot:Getting actions from Agent: demand_generator.
# DEBUG:scse.controller.miniscot:clock: 16
# INFO:scse.controller.miniscot:timestep is = 16
# INFO:scse.controller.miniscot:datetime is = 2019-01-17 00:00:00
# INFO:scse.controller.miniscot:Timestep Reward = 700806042.9086059
# INFO:scse.controller.miniscot:Episode Reward = 11230988454.47236
# DEBUG:scse.controller.miniscot:Getting actions from Agent: renewables_firm.
# DEBUG:scse.modules.production.renewables_firm:renewables_firm produced 1454385.0151851312 MW, sd 458604.9303995793
# DEBUG:scse.controller.miniscot:Getting actions from Agent: cheap_ramp_firm.
# DEBUG:scse.controller.miniscot:Getting actions from Agent: expensive_ramp_firm.
# DEBUG:scse.controller.miniscot:Getting actions from Agent: demand_generator.
# DEBUG:scse.controller.miniscot:clock: 17
# INFO:scse.controller.miniscot:timestep is = 17
# INFO:scse.controller.miniscot:datetime is = 2019-01-18 00:00:00
# INFO:scse.controller.miniscot:Timestep Reward = 711175400.6074052
# INFO:scse.controller.miniscot:Episode Reward = 11942163855.079765
# DEBUG:scse.controller.miniscot:Getting actions from Agent: renewables_firm.
# DEBUG:scse.modules.production.renewables_firm:renewables_firm produced 1310159.906091651 MW, sd 458536.3826163195
# DEBUG:scse.controller.miniscot:Getting actions from Agent: cheap_ramp_firm.
# DEBUG:scse.controller.miniscot:Getting actions from Agent: expensive_ramp_firm.
# DEBUG:scse.controller.miniscot:Getting actions from Agent: demand_generator.
# DEBUG:scse.controller.miniscot:clock: 18
# INFO:scse.controller.miniscot:timestep is = 18
# INFO:scse.controller.miniscot:datetime is = 2019-01-19 00:00:00
# INFO:scse.controller.miniscot:Timestep Reward = 705406396.243666
# INFO:scse.controller.miniscot:Episode Reward = 12647570251.323431
# DEBUG:scse.controller.miniscot:Getting actions from Agent: renewables_firm.
# DEBUG:scse.modules.production.renewables_firm:renewables_firm produced 1494722.069855013 MW, sd 457255.69308274984
# DEBUG:scse.controller.miniscot:Getting actions from Agent: cheap_ramp_firm.
# DEBUG:scse.controller.miniscot:Getting actions from Agent: expensive_ramp_firm.
# DEBUG:scse.controller.miniscot:Getting actions from Agent: demand_generator.
# DEBUG:scse.controller.miniscot:clock: 19
# INFO:scse.controller.miniscot:timestep is = 19
# INFO:scse.controller.miniscot:datetime is = 2019-01-20 00:00:00
# INFO:scse.controller.miniscot:Timestep Reward = 712788882.7942005
# INFO:scse.controller.miniscot:Episode Reward = 13360359134.117632
# DEBUG:scse.controller.miniscot:Getting actions from Agent: renewables_firm.
# DEBUG:scse.modules.production.renewables_firm:renewables_firm produced 2367551.010857541 MW, sd 457882.5971929014
# DEBUG:scse.controller.miniscot:Getting actions from Agent: cheap_ramp_firm.
# DEBUG:scse.controller.miniscot:Getting actions from Agent: expensive_ramp_firm.
# DEBUG:scse.controller.miniscot:Getting actions from Agent: demand_generator.
# DEBUG:scse.controller.miniscot:clock: 20
# INFO:scse.controller.miniscot:timestep is = 20
# INFO:scse.controller.miniscot:datetime is = 2019-01-21 00:00:00
# INFO:scse.controller.miniscot:Timestep Reward = 648338341.0025485
# INFO:scse.controller.miniscot:Episode Reward = 14008697475.12018
# DEBUG:scse.controller.miniscot:Getting actions from Agent: renewables_firm.
# DEBUG:scse.modules.production.renewables_firm:renewables_firm produced 2165214.578104038 MW, sd 460222.7963243919
# DEBUG:scse.controller.miniscot:Getting actions from Agent: cheap_ramp_firm.
# DEBUG:scse.controller.miniscot:Getting actions from Agent: expensive_ramp_firm.
# DEBUG:scse.controller.miniscot:Getting actions from Agent: demand_generator.
# DEBUG:scse.controller.miniscot:clock: 21
# INFO:scse.controller.miniscot:timestep is = 21
# INFO:scse.controller.miniscot:datetime is = 2019-01-22 00:00:00
# INFO:scse.controller.miniscot:Timestep Reward = 727902657.1385585
# INFO:scse.controller.miniscot:Episode Reward = 14736600132.25874
# DEBUG:scse.controller.miniscot:Getting actions from Agent: renewables_firm.
# DEBUG:scse.modules.production.renewables_firm:renewables_firm produced 2064137.936038133 MW, sd 457350.4599703799
# DEBUG:scse.controller.miniscot:Getting actions from Agent: cheap_ramp_firm.
# DEBUG:scse.controller.miniscot:Getting actions from Agent: expensive_ramp_firm.
# DEBUG:scse.controller.miniscot:Getting actions from Agent: demand_generator.
# DEBUG:scse.controller.miniscot:clock: 22
# INFO:scse.controller.miniscot:timestep is = 22
# INFO:scse.controller.miniscot:datetime is = 2019-01-23 00:00:00
# INFO:scse.controller.miniscot:Timestep Reward = 735565517.4415253
# INFO:scse.controller.miniscot:Episode Reward = 15472165649.700264
# DEBUG:scse.controller.miniscot:Getting actions from Agent: renewables_firm.
# DEBUG:scse.modules.production.renewables_firm:renewables_firm produced 732764.6814507094 MW, sd 458831.82236457826
# DEBUG:scse.controller.miniscot:Getting actions from Agent: cheap_ramp_firm.
# DEBUG:scse.controller.miniscot:Getting actions from Agent: expensive_ramp_firm.
# DEBUG:scse.controller.miniscot:Getting actions from Agent: demand_generator.
# DEBUG:scse.controller.miniscot:clock: 23
# INFO:scse.controller.miniscot:timestep is = 23
# INFO:scse.controller.miniscot:datetime is = 2019-01-24 00:00:00
# INFO:scse.controller.miniscot:Timestep Reward = 682310587.2580284
# INFO:scse.controller.miniscot:Episode Reward = 16154476236.958292
# DEBUG:scse.controller.miniscot:Getting actions from Agent: renewables_firm.
# DEBUG:scse.modules.production.renewables_firm:renewables_firm produced 1097354.5653133388 MW, sd 460147.22721965826
# DEBUG:scse.controller.miniscot:Getting actions from Agent: cheap_ramp_firm.
# DEBUG:scse.controller.miniscot:Getting actions from Agent: expensive_ramp_firm.
# DEBUG:scse.controller.miniscot:Getting actions from Agent: demand_generator.
# DEBUG:scse.controller.miniscot:clock: 24
# INFO:scse.controller.miniscot:timestep is = 24
# INFO:scse.controller.miniscot:datetime is = 2019-01-25 00:00:00
# INFO:scse.controller.miniscot:Timestep Reward = 696894182.6125336
# INFO:scse.controller.miniscot:Episode Reward = 16851370419.570826
# DEBUG:scse.controller.miniscot:Getting actions from Agent: renewables_firm.
# DEBUG:scse.modules.production.renewables_firm:renewables_firm produced 1056121.8120962265 MW, sd 458158.08584811544
# DEBUG:scse.controller.miniscot:Getting actions from Agent: cheap_ramp_firm.
# DEBUG:scse.controller.miniscot:Getting actions from Agent: expensive_ramp_firm.
# DEBUG:scse.controller.miniscot:Getting actions from Agent: demand_generator.
# DEBUG:scse.controller.miniscot:clock: 25
# INFO:scse.controller.miniscot:timestep is = 25
# INFO:scse.controller.miniscot:datetime is = 2019-01-26 00:00:00
# INFO:scse.controller.miniscot:Timestep Reward = 695244872.483849
# INFO:scse.controller.miniscot:Episode Reward = 17546615292.054676
# DEBUG:scse.controller.miniscot:Getting actions from Agent: renewables_firm.
# DEBUG:scse.modules.production.renewables_firm:renewables_firm produced 676210.1159013837 MW, sd 457554.48322658543
# DEBUG:scse.controller.miniscot:Getting actions from Agent: cheap_ramp_firm.
# DEBUG:scse.controller.miniscot:Getting actions from Agent: expensive_ramp_firm.
# DEBUG:scse.controller.miniscot:Getting actions from Agent: demand_generator.
# DEBUG:scse.controller.miniscot:clock: 26
# INFO:scse.controller.miniscot:timestep is = 26
# INFO:scse.controller.miniscot:datetime is = 2019-01-27 00:00:00
# INFO:scse.controller.miniscot:Timestep Reward = 680048404.6360554
# INFO:scse.controller.miniscot:Episode Reward = 18226663696.69073
# DEBUG:scse.controller.miniscot:Getting actions from Agent: renewables_firm.
# DEBUG:scse.modules.production.renewables_firm:renewables_firm produced 1551089.1268980992 MW, sd 461085.0392677327
# DEBUG:scse.controller.miniscot:Getting actions from Agent: cheap_ramp_firm.
# DEBUG:scse.controller.miniscot:Getting actions from Agent: expensive_ramp_firm.
# DEBUG:scse.controller.miniscot:Getting actions from Agent: demand_generator.
# DEBUG:scse.controller.miniscot:clock: 27
# INFO:scse.controller.miniscot:timestep is = 27
# INFO:scse.controller.miniscot:datetime is = 2019-01-28 00:00:00
# INFO:scse.controller.miniscot:Timestep Reward = 665310339.0983282
# INFO:scse.controller.miniscot:Episode Reward = 18891974035.78906
# DEBUG:scse.controller.miniscot:Getting actions from Agent: renewables_firm.
# DEBUG:scse.modules.production.renewables_firm:renewables_firm produced 1661495.1165189222 MW, sd 458078.5547296448
# DEBUG:scse.controller.miniscot:Getting actions from Agent: cheap_ramp_firm.
# DEBUG:scse.controller.miniscot:Getting actions from Agent: expensive_ramp_firm.
# DEBUG:scse.controller.miniscot:Getting actions from Agent: demand_generator.
# DEBUG:scse.controller.miniscot:clock: 28
# INFO:scse.controller.miniscot:timestep is = 28
# INFO:scse.controller.miniscot:datetime is = 2019-01-29 00:00:00
# INFO:scse.controller.miniscot:Timestep Reward = 655483859.9749578
# INFO:scse.controller.miniscot:Episode Reward = 19547457895.764015
# DEBUG:scse.controller.miniscot:Getting actions from Agent: renewables_firm.
# DEBUG:scse.modules.production.renewables_firm:renewables_firm produced 2123206.115698926 MW, sd 457300.2100015064
# DEBUG:scse.controller.miniscot:Getting actions from Agent: cheap_ramp_firm.
# DEBUG:scse.controller.miniscot:Getting actions from Agent: expensive_ramp_firm.
# DEBUG:scse.controller.miniscot:Getting actions from Agent: demand_generator.
# DEBUG:scse.controller.miniscot:clock: 29
# INFO:scse.controller.miniscot:timestep is = 29
# INFO:scse.controller.miniscot:datetime is = 2019-01-30 00:00:00
# INFO:scse.controller.miniscot:Timestep Reward = 638400889.7895792
# INFO:scse.controller.miniscot:Episode Reward = 20185858785.553593
# DEBUG:scse.controller.miniscot:Getting actions from Agent: renewables_firm.
# DEBUG:scse.modules.production.renewables_firm:renewables_firm produced 963749.0260858075 MW, sd 458968.2800947368
# DEBUG:scse.controller.miniscot:Getting actions from Agent: cheap_ramp_firm.
# DEBUG:scse.controller.miniscot:Getting actions from Agent: expensive_ramp_firm.
# DEBUG:scse.controller.miniscot:Getting actions from Agent: demand_generator.
# DEBUG:scse.controller.miniscot:clock: 30
# INFO:scse.controller.miniscot:timestep is = 30
# INFO:scse.controller.miniscot:datetime is = 2019-01-31 00:00:00
# INFO:scse.controller.miniscot:Timestep Reward = 691549961.0434322
# INFO:scse.controller.miniscot:Episode Reward = 20877408746.597023
# DEBUG:scse.controller.miniscot:Getting actions from Agent: renewables_firm.
# DEBUG:scse.modules.production.renewables_firm:renewables_firm produced 1017372.7649680839 MW, sd 458801.75395640405
# DEBUG:scse.controller.miniscot:Getting actions from Agent: cheap_ramp_firm.
# DEBUG:scse.controller.miniscot:Getting actions from Agent: expensive_ramp_firm.
# DEBUG:scse.controller.miniscot:Getting actions from Agent: demand_generator.
# DEBUG:scse.controller.miniscot:clock: 31
# INFO:scse.controller.miniscot:timestep is = 31
# INFO:scse.controller.miniscot:datetime is = 2019-02-01 00:00:00
# INFO:scse.controller.miniscot:Timestep Reward = 675045331.9245896
# INFO:scse.controller.miniscot:Episode Reward = 21552454078.521614
# DEBUG:scse.controller.miniscot:Getting actions from Agent: renewables_firm.
# DEBUG:scse.modules.production.renewables_firm:renewables_firm produced 1292260.8134641568 MW, sd 458226.1718043908
# DEBUG:scse.controller.miniscot:Getting actions from Agent: cheap_ramp_firm.
# DEBUG:scse.controller.miniscot:Getting actions from Agent: expensive_ramp_firm.
# DEBUG:scse.controller.miniscot:Getting actions from Agent: demand_generator.
# DEBUG:scse.controller.miniscot:clock: 32
# INFO:scse.controller.miniscot:timestep is = 32
# INFO:scse.controller.miniscot:datetime is = 2019-02-02 00:00:00
# INFO:scse.controller.miniscot:Timestep Reward = 657662811.9440197
# INFO:scse.controller.miniscot:Episode Reward = 22210116890.465633
# DEBUG:scse.controller.miniscot:Getting actions from Agent: renewables_firm.
# DEBUG:scse.modules.production.renewables_firm:renewables_firm produced 1679057.9240651375 MW, sd 457261.76313290256
# DEBUG:scse.controller.miniscot:Getting actions from Agent: cheap_ramp_firm.
# DEBUG:scse.controller.miniscot:Getting actions from Agent: expensive_ramp_firm.
# DEBUG:scse.controller.miniscot:Getting actions from Agent: demand_generator.
# DEBUG:scse.controller.miniscot:clock: 33
# INFO:scse.controller.miniscot:timestep is = 33
# INFO:scse.controller.miniscot:datetime is = 2019-02-03 00:00:00
# INFO:scse.controller.miniscot:Timestep Reward = 579684970.1086328
# INFO:scse.controller.miniscot:Episode Reward = 22789801860.574265
# DEBUG:scse.controller.miniscot:Getting actions from Agent: renewables_firm.
# DEBUG:scse.modules.production.renewables_firm:renewables_firm produced 1770749.631527226 MW, sd 457861.03109340067
# DEBUG:scse.controller.miniscot:Getting actions from Agent: cheap_ramp_firm.
# DEBUG:scse.controller.miniscot:Getting actions from Agent: expensive_ramp_firm.
# DEBUG:scse.controller.miniscot:Getting actions from Agent: demand_generator.
# DEBUG:scse.controller.miniscot:clock: 34
# INFO:scse.controller.miniscot:timestep is = 34
# INFO:scse.controller.miniscot:datetime is = 2019-02-04 00:00:00
# INFO:scse.controller.miniscot:Timestep Reward = 546503588.7317332
# INFO:scse.controller.miniscot:Episode Reward = 23336305449.305996
# DEBUG:scse.controller.miniscot:Getting actions from Agent: renewables_firm.
# DEBUG:scse.modules.production.renewables_firm:renewables_firm produced 1519677.5259650918 MW, sd 458399.72417961666
# DEBUG:scse.controller.miniscot:Getting actions from Agent: cheap_ramp_firm.
# DEBUG:scse.controller.miniscot:Getting actions from Agent: expensive_ramp_firm.
# DEBUG:scse.controller.miniscot:Getting actions from Agent: demand_generator.
# DEBUG:scse.controller.miniscot:clock: 35
# INFO:scse.controller.miniscot:timestep is = 35
# INFO:scse.controller.miniscot:datetime is = 2019-02-05 00:00:00
# INFO:scse.controller.miniscot:Timestep Reward = 646231818.95444
# INFO:scse.controller.miniscot:Episode Reward = 23982537268.260437
# DEBUG:scse.controller.miniscot:Getting actions from Agent: renewables_firm.
# DEBUG:scse.modules.production.renewables_firm:renewables_firm produced 1360393.3556155937 MW, sd 457362.75037582027
# DEBUG:scse.controller.miniscot:Getting actions from Agent: cheap_ramp_firm.
# DEBUG:scse.controller.miniscot:Getting actions from Agent: expensive_ramp_firm.
# DEBUG:scse.controller.miniscot:Getting actions from Agent: demand_generator.
# DEBUG:scse.controller.miniscot:clock: 36
# INFO:scse.controller.miniscot:timestep is = 36
# INFO:scse.controller.miniscot:datetime is = 2019-02-06 00:00:00
# INFO:scse.controller.miniscot:Timestep Reward = 707415734.2246238
# INFO:scse.controller.miniscot:Episode Reward = 24689953002.48506
# DEBUG:scse.controller.miniscot:Getting actions from Agent: renewables_firm.
# DEBUG:scse.modules.production.renewables_firm:renewables_firm produced 1190104.49655029 MW, sd 458300.45074340224
# DEBUG:scse.controller.miniscot:Getting actions from Agent: cheap_ramp_firm.
# DEBUG:scse.controller.miniscot:Getting actions from Agent: expensive_ramp_firm.
# DEBUG:scse.controller.miniscot:Getting actions from Agent: demand_generator.
# DEBUG:scse.controller.miniscot:clock: 37
# INFO:scse.controller.miniscot:timestep is = 37
# INFO:scse.controller.miniscot:datetime is = 2019-02-07 00:00:00
# INFO:scse.controller.miniscot:Timestep Reward = 700604179.8620116
# INFO:scse.controller.miniscot:Episode Reward = 25390557182.347073
# DEBUG:scse.controller.miniscot:Getting actions from Agent: renewables_firm.
# DEBUG:scse.modules.production.renewables_firm:renewables_firm produced 1149024.3278424703 MW, sd 458602.23628277285
# DEBUG:scse.controller.miniscot:Getting actions from Agent: cheap_ramp_firm.
# DEBUG:scse.controller.miniscot:Getting actions from Agent: expensive_ramp_firm.
# DEBUG:scse.controller.miniscot:Getting actions from Agent: demand_generator.
# DEBUG:scse.controller.miniscot:clock: 38
# INFO:scse.controller.miniscot:timestep is = 38
# INFO:scse.controller.miniscot:datetime is = 2019-02-08 00:00:00
# INFO:scse.controller.miniscot:Timestep Reward = 686647181.2710795
# INFO:scse.controller.miniscot:Episode Reward = 26077204363.618153
# DEBUG:scse.controller.miniscot:Getting actions from Agent: renewables_firm.
# DEBUG:scse.modules.production.renewables_firm:renewables_firm produced 1310061.8761838586 MW, sd 458158.3359106612
# DEBUG:scse.controller.miniscot:Getting actions from Agent: cheap_ramp_firm.
# DEBUG:scse.controller.miniscot:Getting actions from Agent: expensive_ramp_firm.
# DEBUG:scse.controller.miniscot:Getting actions from Agent: demand_generator.
# DEBUG:scse.controller.miniscot:clock: 39
# INFO:scse.controller.miniscot:timestep is = 39
# INFO:scse.controller.miniscot:datetime is = 2019-02-09 00:00:00
# INFO:scse.controller.miniscot:Timestep Reward = 632956360.4834193
# INFO:scse.controller.miniscot:Episode Reward = 26710160724.10157
# DEBUG:scse.controller.miniscot:Getting actions from Agent: renewables_firm.
# DEBUG:scse.modules.production.renewables_firm:renewables_firm produced 2283590.6103293602 MW, sd 457255.7226343694
# DEBUG:scse.controller.miniscot:Getting actions from Agent: cheap_ramp_firm.
# DEBUG:scse.controller.miniscot:Getting actions from Agent: expensive_ramp_firm.
# DEBUG:scse.controller.miniscot:Getting actions from Agent: demand_generator.
# DEBUG:scse.controller.miniscot:clock: 40
# INFO:scse.controller.miniscot:timestep is = 40
# INFO:scse.controller.miniscot:datetime is = 2019-02-10 00:00:00
# INFO:scse.controller.miniscot:Timestep Reward = 549837094.8601431
# INFO:scse.controller.miniscot:Episode Reward = 27259997818.96171
# DEBUG:scse.controller.miniscot:Getting actions from Agent: renewables_firm.
# DEBUG:scse.modules.production.renewables_firm:renewables_firm produced 2479278.6158622694 MW, sd 458569.804246885
# DEBUG:scse.controller.miniscot:Getting actions from Agent: cheap_ramp_firm.
# DEBUG:scse.controller.miniscot:Getting actions from Agent: expensive_ramp_firm.
# DEBUG:scse.controller.miniscot:Getting actions from Agent: demand_generator.
# DEBUG:scse.controller.miniscot:clock: 41
# INFO:scse.controller.miniscot:timestep is = 41
# INFO:scse.controller.miniscot:datetime is = 2019-02-11 00:00:00
# INFO:scse.controller.miniscot:Timestep Reward = 533379391.03571147
# INFO:scse.controller.miniscot:Episode Reward = 27793377209.997425
# DEBUG:scse.controller.miniscot:Getting actions from Agent: renewables_firm.
# DEBUG:scse.modules.production.renewables_firm:renewables_firm produced 1198676.4383601218 MW, sd 461143.3967438156
# DEBUG:scse.controller.miniscot:Getting actions from Agent: cheap_ramp_firm.
# DEBUG:scse.controller.miniscot:Getting actions from Agent: expensive_ramp_firm.
# DEBUG:scse.controller.miniscot:Getting actions from Agent: demand_generator.
# DEBUG:scse.controller.miniscot:clock: 42
# INFO:scse.controller.miniscot:timestep is = 42
# INFO:scse.controller.miniscot:datetime is = 2019-02-12 00:00:00
# INFO:scse.controller.miniscot:Timestep Reward = 643588561.5319388
# INFO:scse.controller.miniscot:Episode Reward = 28436965771.529366
# DEBUG:scse.controller.miniscot:Getting actions from Agent: renewables_firm.
# DEBUG:scse.modules.production.renewables_firm:renewables_firm produced 1715772.3392950126 MW, sd 457602.4597689243
# DEBUG:scse.controller.miniscot:Getting actions from Agent: cheap_ramp_firm.
# DEBUG:scse.controller.miniscot:Getting actions from Agent: expensive_ramp_firm.
# DEBUG:scse.controller.miniscot:Getting actions from Agent: demand_generator.
# DEBUG:scse.controller.miniscot:clock: 43
# INFO:scse.controller.miniscot:timestep is = 43
# INFO:scse.controller.miniscot:datetime is = 2019-02-13 00:00:00
# INFO:scse.controller.miniscot:Timestep Reward = 619275354.5299389
# INFO:scse.controller.miniscot:Episode Reward = 29056241126.059303
# DEBUG:scse.controller.miniscot:Getting actions from Agent: renewables_firm.
# DEBUG:scse.modules.production.renewables_firm:renewables_firm produced 50987.931203318585 MW, sd 458444.3722145226
# DEBUG:scse.controller.miniscot:Getting actions from Agent: cheap_ramp_firm.
# DEBUG:scse.controller.miniscot:Getting actions from Agent: expensive_ramp_firm.
# DEBUG:scse.controller.miniscot:Getting actions from Agent: demand_generator.
# DEBUG:scse.controller.miniscot:clock: 44
# INFO:scse.controller.miniscot:timestep is = 44
# INFO:scse.controller.miniscot:datetime is = 2019-02-14 00:00:00
# INFO:scse.controller.miniscot:Timestep Reward = 655039517.2481327
# INFO:scse.controller.miniscot:Episode Reward = 29711280643.307434
# DEBUG:scse.controller.miniscot:Getting actions from Agent: renewables_firm.
# DEBUG:scse.modules.production.renewables_firm:renewables_firm produced 476861.6790754494 MW, sd 482062.1487734409
# DEBUG:scse.controller.miniscot:Getting actions from Agent: cheap_ramp_firm.
# DEBUG:scse.controller.miniscot:Getting actions from Agent: expensive_ramp_firm.
# DEBUG:scse.controller.miniscot:Getting actions from Agent: demand_generator.
# DEBUG:scse.controller.miniscot:clock: 45
# INFO:scse.controller.miniscot:timestep is = 45
# INFO:scse.controller.miniscot:datetime is = 2019-02-15 00:00:00
# INFO:scse.controller.miniscot:Timestep Reward = 672074467.163018
# INFO:scse.controller.miniscot:Episode Reward = 30383355110.47045
# DEBUG:scse.controller.miniscot:Getting actions from Agent: renewables_firm.
# DEBUG:scse.modules.production.renewables_firm:renewables_firm produced 535656.3515529506 MW, sd 463584.0967010957
# DEBUG:scse.controller.miniscot:Getting actions from Agent: cheap_ramp_firm.
# DEBUG:scse.controller.miniscot:Getting actions from Agent: expensive_ramp_firm.
# DEBUG:scse.controller.miniscot:Getting actions from Agent: demand_generator.
# DEBUG:scse.controller.miniscot:clock: 46
# INFO:scse.controller.miniscot:timestep is = 46
# INFO:scse.controller.miniscot:datetime is = 2019-02-16 00:00:00
# INFO:scse.controller.miniscot:Timestep Reward = 674426254.062118
# INFO:scse.controller.miniscot:Episode Reward = 31057781364.53257
# DEBUG:scse.controller.miniscot:Getting actions from Agent: renewables_firm.
# DEBUG:scse.modules.production.renewables_firm:renewables_firm produced 727395.8586328643 MW, sd 462493.32233423064
# DEBUG:scse.controller.miniscot:Getting actions from Agent: cheap_ramp_firm.
# DEBUG:scse.controller.miniscot:Getting actions from Agent: expensive_ramp_firm.
# DEBUG:scse.controller.miniscot:Getting actions from Agent: demand_generator.
# DEBUG:scse.controller.miniscot:clock: 47
# INFO:scse.controller.miniscot:timestep is = 47
# INFO:scse.controller.miniscot:datetime is = 2019-02-17 00:00:00
# INFO:scse.controller.miniscot:Timestep Reward = 682095834.3453146
# INFO:scse.controller.miniscot:Episode Reward = 31739877198.877884
# DEBUG:scse.controller.miniscot:Getting actions from Agent: renewables_firm.
# DEBUG:scse.modules.production.renewables_firm:renewables_firm produced 439520.13620903227 MW, sd 460451.3134096554
# DEBUG:scse.controller.miniscot:Getting actions from Agent: cheap_ramp_firm.
# DEBUG:scse.controller.miniscot:Getting actions from Agent: expensive_ramp_firm.
# DEBUG:scse.controller.miniscot:Getting actions from Agent: demand_generator.
# DEBUG:scse.controller.miniscot:clock: 48
# INFO:scse.controller.miniscot:timestep is = 48
# INFO:scse.controller.miniscot:datetime is = 2019-02-18 00:00:00
# INFO:scse.controller.miniscot:Timestep Reward = 670580805.4483613
# INFO:scse.controller.miniscot:Episode Reward = 32410458004.326244
# DEBUG:scse.controller.miniscot:Getting actions from Agent: renewables_firm.
# DEBUG:scse.modules.production.renewables_firm:renewables_firm produced 432823.5149731961 MW, sd 464246.6103500545
# DEBUG:scse.controller.miniscot:Getting actions from Agent: cheap_ramp_firm.
# DEBUG:scse.controller.miniscot:Getting actions from Agent: expensive_ramp_firm.
# DEBUG:scse.controller.miniscot:Getting actions from Agent: demand_generator.
# DEBUG:scse.controller.miniscot:clock: 49
# INFO:scse.controller.miniscot:timestep is = 49
# INFO:scse.controller.miniscot:datetime is = 2019-02-19 00:00:00
# INFO:scse.controller.miniscot:Timestep Reward = 670312940.5989279
# INFO:scse.controller.miniscot:Episode Reward = 33080770944.92517
# DEBUG:scse.controller.miniscot:Getting actions from Agent: renewables_firm.
# DEBUG:scse.modules.production.renewables_firm:renewables_firm produced 891448.0181506053 MW, sd 465507.34639647027
# DEBUG:scse.controller.miniscot:Getting actions from Agent: cheap_ramp_firm.
# DEBUG:scse.controller.miniscot:Getting actions from Agent: expensive_ramp_firm.
# DEBUG:scse.controller.miniscot:Getting actions from Agent: demand_generator.
# DEBUG:scse.controller.miniscot:clock: 50
# INFO:scse.controller.miniscot:timestep is = 50
# INFO:scse.controller.miniscot:datetime is = 2019-02-20 00:00:00
# INFO:scse.controller.miniscot:Timestep Reward = 661341605.4442225
# INFO:scse.controller.miniscot:Episode Reward = 33742112550.369392
# DEBUG:scse.controller.miniscot:Getting actions from Agent: renewables_firm.
# DEBUG:scse.modules.production.renewables_firm:renewables_firm produced 852654.6077583068 MW, sd 459222.33708934294
# DEBUG:scse.controller.miniscot:Getting actions from Agent: cheap_ramp_firm.
# DEBUG:scse.controller.miniscot:Getting actions from Agent: expensive_ramp_firm.
# DEBUG:scse.controller.miniscot:Getting actions from Agent: demand_generator.
# DEBUG:scse.controller.miniscot:clock: 51
# INFO:scse.controller.miniscot:timestep is = 51
# INFO:scse.controller.miniscot:datetime is = 2019-02-21 00:00:00
# INFO:scse.controller.miniscot:Timestep Reward = 654584562.1614869
# INFO:scse.controller.miniscot:Episode Reward = 34396697112.530876
# DEBUG:scse.controller.miniscot:Getting actions from Agent: renewables_firm.
# DEBUG:scse.modules.production.renewables_firm:renewables_firm produced 1482150.3040322415 MW, sd 459250.9829866076
# DEBUG:scse.controller.miniscot:Getting actions from Agent: cheap_ramp_firm.
# DEBUG:scse.controller.miniscot:Getting actions from Agent: expensive_ramp_firm.
# DEBUG:scse.controller.miniscot:Getting actions from Agent: demand_generator.
# DEBUG:scse.controller.miniscot:clock: 52
# INFO:scse.controller.miniscot:timestep is = 52
# INFO:scse.controller.miniscot:datetime is = 2019-02-22 00:00:00
# INFO:scse.controller.miniscot:Timestep Reward = 581114870.7660462
# INFO:scse.controller.miniscot:Episode Reward = 34977811983.29692
# DEBUG:scse.controller.miniscot:Getting actions from Agent: renewables_firm.
# DEBUG:scse.modules.production.renewables_firm:renewables_firm produced 1840568.1196447941 MW, sd 458585.2680469915
# DEBUG:scse.controller.miniscot:Getting actions from Agent: cheap_ramp_firm.
# DEBUG:scse.controller.miniscot:Getting actions from Agent: expensive_ramp_firm.
# DEBUG:scse.controller.miniscot:Getting actions from Agent: demand_generator.
# DEBUG:scse.controller.miniscot:clock: 53
# INFO:scse.controller.miniscot:timestep is = 53
# INFO:scse.controller.miniscot:datetime is = 2019-02-23 00:00:00
# INFO:scse.controller.miniscot:Timestep Reward = 538513247.6981586
# INFO:scse.controller.miniscot:Episode Reward = 35516325230.99508
# DEBUG:scse.controller.miniscot:Getting actions from Agent: renewables_firm.
# DEBUG:scse.modules.production.renewables_firm:renewables_firm produced 1827744.9104718033 MW, sd 457301.0862615635
# DEBUG:scse.controller.miniscot:Getting actions from Agent: cheap_ramp_firm.
# DEBUG:scse.controller.miniscot:Getting actions from Agent: expensive_ramp_firm.
# DEBUG:scse.controller.miniscot:Getting actions from Agent: demand_generator.
# DEBUG:scse.controller.miniscot:clock: 54
# INFO:scse.controller.miniscot:timestep is = 54
# INFO:scse.controller.miniscot:datetime is = 2019-02-24 00:00:00
# INFO:scse.controller.miniscot:Timestep Reward = 499092446.5944986
# INFO:scse.controller.miniscot:Episode Reward = 36015417677.58958
# DEBUG:scse.controller.miniscot:Getting actions from Agent: renewables_firm.
# DEBUG:scse.modules.production.renewables_firm:renewables_firm produced 951785.9766535421 MW, sd 457864.5649614637
# DEBUG:scse.controller.miniscot:Getting actions from Agent: cheap_ramp_firm.
# DEBUG:scse.controller.miniscot:Getting actions from Agent: expensive_ramp_firm.
# DEBUG:scse.controller.miniscot:Getting actions from Agent: demand_generator.
# DEBUG:scse.controller.miniscot:clock: 55
# INFO:scse.controller.miniscot:timestep is = 55
# INFO:scse.controller.miniscot:datetime is = 2019-02-25 00:00:00
# INFO:scse.controller.miniscot:Timestep Reward = 607001580.862603
# INFO:scse.controller.miniscot:Episode Reward = 36622419258.45218
# DEBUG:scse.controller.miniscot:Getting actions from Agent: renewables_firm.
# DEBUG:scse.modules.production.renewables_firm:renewables_firm produced 813031.506707934 MW, sd 457946.8316912226
# DEBUG:scse.controller.miniscot:Getting actions from Agent: cheap_ramp_firm.
# DEBUG:scse.controller.miniscot:Getting actions from Agent: expensive_ramp_firm.
# DEBUG:scse.controller.miniscot:Getting actions from Agent: demand_generator.
# DEBUG:scse.controller.miniscot:clock: 56
# INFO:scse.controller.miniscot:timestep is = 56
# INFO:scse.controller.miniscot:datetime is = 2019-02-26 00:00:00
# INFO:scse.controller.miniscot:Timestep Reward = 671834049.7953627
# INFO:scse.controller.miniscot:Episode Reward = 37294253308.24754
# DEBUG:scse.controller.miniscot:Getting actions from Agent: renewables_firm.
# DEBUG:scse.modules.production.renewables_firm:renewables_firm produced 1077585.2689781957 MW, sd 459179.60000328446
# DEBUG:scse.controller.miniscot:Getting actions from Agent: cheap_ramp_firm.
# DEBUG:scse.controller.miniscot:Getting actions from Agent: expensive_ramp_firm.
# DEBUG:scse.controller.miniscot:Getting actions from Agent: demand_generator.
# DEBUG:scse.controller.miniscot:clock: 57
# INFO:scse.controller.miniscot:timestep is = 57
# INFO:scse.controller.miniscot:datetime is = 2019-02-27 00:00:00
# INFO:scse.controller.miniscot:Timestep Reward = 662806178.4545122
# INFO:scse.controller.miniscot:Episode Reward = 37957059486.70206
# DEBUG:scse.controller.miniscot:Getting actions from Agent: renewables_firm.
# DEBUG:scse.modules.production.renewables_firm:renewables_firm produced 1355482.613374586 MW, sd 458526.5567881659
# DEBUG:scse.controller.miniscot:Getting actions from Agent: cheap_ramp_firm.
# DEBUG:scse.controller.miniscot:Getting actions from Agent: expensive_ramp_firm.
# DEBUG:scse.controller.miniscot:Getting actions from Agent: demand_generator.
# DEBUG:scse.controller.miniscot:clock: 58
# INFO:scse.controller.miniscot:timestep is = 58
# INFO:scse.controller.miniscot:datetime is = 2019-02-28 00:00:00
# INFO:scse.controller.miniscot:Timestep Reward = 675898685.2621667
# INFO:scse.controller.miniscot:Episode Reward = 38632958171.964226
# DEBUG:scse.controller.miniscot:Getting actions from Agent: renewables_firm.
# DEBUG:scse.modules.production.renewables_firm:renewables_firm produced 522736.7715700166 MW, sd 458780.11256866716
# DEBUG:scse.controller.miniscot:Getting actions from Agent: cheap_ramp_firm.
# DEBUG:scse.controller.miniscot:Getting actions from Agent: expensive_ramp_firm.
# DEBUG:scse.controller.miniscot:Getting actions from Agent: demand_generator.
# DEBUG:scse.controller.miniscot:clock: 59
# INFO:scse.controller.miniscot:timestep is = 59
# INFO:scse.controller.miniscot:datetime is = 2019-03-01 00:00:00
# INFO:scse.controller.miniscot:Timestep Reward = 673909470.8628006
# INFO:scse.controller.miniscot:Episode Reward = 39306867642.82703
# DEBUG:scse.controller.miniscot:Getting actions from Agent: renewables_firm.
# DEBUG:scse.modules.production.renewables_firm:renewables_firm produced 1447250.509113041 MW, sd 462597.16276648495
# DEBUG:scse.controller.miniscot:Getting actions from Agent: cheap_ramp_firm.
# DEBUG:scse.controller.miniscot:Getting actions from Agent: expensive_ramp_firm.
# DEBUG:scse.controller.miniscot:Getting actions from Agent: demand_generator.
# DEBUG:scse.controller.miniscot:clock: 60
# INFO:scse.controller.miniscot:timestep is = 60
# INFO:scse.controller.miniscot:datetime is = 2019-03-02 00:00:00
# INFO:scse.controller.miniscot:Timestep Reward = 688031392.7829711
# INFO:scse.controller.miniscot:Episode Reward = 39994899035.61
# DEBUG:scse.controller.miniscot:Getting actions from Agent: renewables_firm.
# DEBUG:scse.modules.production.renewables_firm:renewables_firm produced 2078679.4252647979 MW, sd 457242.6282393106
# DEBUG:scse.controller.miniscot:Getting actions from Agent: cheap_ramp_firm.
# DEBUG:scse.controller.miniscot:Getting actions from Agent: expensive_ramp_firm.
# DEBUG:scse.controller.miniscot:Getting actions from Agent: demand_generator.
# DEBUG:scse.controller.miniscot:clock: 61
# INFO:scse.controller.miniscot:timestep is = 61
# INFO:scse.controller.miniscot:datetime is = 2019-03-03 00:00:00
# INFO:scse.controller.miniscot:Timestep Reward = 589655638.9170746
# INFO:scse.controller.miniscot:Episode Reward = 40584554674.52708
# DEBUG:scse.controller.miniscot:Getting actions from Agent: renewables_firm.
# DEBUG:scse.modules.production.renewables_firm:renewables_firm produced 1773053.477906068 MW, sd 458027.3801643273
# DEBUG:scse.controller.miniscot:Getting actions from Agent: cheap_ramp_firm.
# DEBUG:scse.controller.miniscot:Getting actions from Agent: expensive_ramp_firm.
# DEBUG:scse.controller.miniscot:Getting actions from Agent: demand_generator.
# DEBUG:scse.controller.miniscot:clock: 62
# INFO:scse.controller.miniscot:timestep is = 62
# INFO:scse.controller.miniscot:datetime is = 2019-03-04 00:00:00
# INFO:scse.controller.miniscot:Timestep Reward = 601805160.2492936
# INFO:scse.controller.miniscot:Episode Reward = 41186359834.77637
# DEBUG:scse.controller.miniscot:Getting actions from Agent: renewables_firm.
# DEBUG:scse.modules.production.renewables_firm:renewables_firm produced 2116758.862762595 MW, sd 458403.1543336114
# DEBUG:scse.controller.miniscot:Getting actions from Agent: cheap_ramp_firm.
# DEBUG:scse.controller.miniscot:Getting actions from Agent: expensive_ramp_firm.
# DEBUG:scse.controller.miniscot:Getting actions from Agent: demand_generator.
# DEBUG:scse.controller.miniscot:clock: 63
# INFO:scse.controller.miniscot:timestep is = 63
# INFO:scse.controller.miniscot:datetime is = 2019-03-05 00:00:00
# INFO:scse.controller.miniscot:Timestep Reward = 587943267.5307164
# INFO:scse.controller.miniscot:Episode Reward = 41774303102.30708
# DEBUG:scse.controller.miniscot:Getting actions from Agent: renewables_firm.
# DEBUG:scse.modules.production.renewables_firm:renewables_firm produced 1613230.091235111 MW, sd 457284.53417482215
# DEBUG:scse.controller.miniscot:Getting actions from Agent: cheap_ramp_firm.
# DEBUG:scse.controller.miniscot:Getting actions from Agent: expensive_ramp_firm.
# DEBUG:scse.controller.miniscot:Getting actions from Agent: demand_generator.
# DEBUG:scse.controller.miniscot:clock: 64
# INFO:scse.controller.miniscot:timestep is = 64
# INFO:scse.controller.miniscot:datetime is = 2019-03-06 00:00:00
# INFO:scse.controller.miniscot:Timestep Reward = 632695387.0460144
# INFO:scse.controller.miniscot:Episode Reward = 42406998489.353096
# DEBUG:scse.controller.miniscot:Getting actions from Agent: renewables_firm.
# DEBUG:scse.modules.production.renewables_firm:renewables_firm produced 1742640.5069021622 MW, sd 458387.171311973
# DEBUG:scse.controller.miniscot:Getting actions from Agent: cheap_ramp_firm.
# DEBUG:scse.controller.miniscot:Getting actions from Agent: expensive_ramp_firm.
# DEBUG:scse.controller.miniscot:Getting actions from Agent: demand_generator.
# DEBUG:scse.controller.miniscot:clock: 65
# INFO:scse.controller.miniscot:timestep is = 65
# INFO:scse.controller.miniscot:datetime is = 2019-03-07 00:00:00
# INFO:scse.controller.miniscot:Timestep Reward = 644539669.1500723
# INFO:scse.controller.miniscot:Episode Reward = 43051538158.50317
# DEBUG:scse.controller.miniscot:Getting actions from Agent: renewables_firm.
# DEBUG:scse.modules.production.renewables_firm:renewables_firm produced 1407602.786088101 MW, sd 459485.8920349384
# DEBUG:scse.controller.miniscot:Getting actions from Agent: cheap_ramp_firm.
# DEBUG:scse.controller.miniscot:Getting actions from Agent: expensive_ramp_firm.
# DEBUG:scse.controller.miniscot:Getting actions from Agent: demand_generator.
# DEBUG:scse.controller.miniscot:clock: 66
# INFO:scse.controller.miniscot:timestep is = 66
# INFO:scse.controller.miniscot:datetime is = 2019-03-08 00:00:00
# INFO:scse.controller.miniscot:Timestep Reward = 673143752.9976617
# INFO:scse.controller.miniscot:Episode Reward = 43724681911.50083
# DEBUG:scse.controller.miniscot:Getting actions from Agent: renewables_firm.
# DEBUG:scse.modules.production.renewables_firm:renewables_firm produced 1113060.3826673932 MW, sd 458456.21713366243
# DEBUG:scse.controller.miniscot:Getting actions from Agent: cheap_ramp_firm.
# DEBUG:scse.controller.miniscot:Getting actions from Agent: expensive_ramp_firm.
# ...
# DEBUG:scse.controller.miniscot:Getting actions from Agent: expensive_ramp_firm.
# DEBUG:scse.controller.miniscot:Getting actions from Agent: demand_generator.
# DEBUG:scse.controller.miniscot:clock: 398
# INFO:scse.controller.miniscot:timestep is = 398
# INFO:scse.controller.miniscot:datetime is = 2020-02-03 00:00:00
# INFO:scse.controller.miniscot:Timestep Reward = 693096349.6471947
# INFO:scse.controller.miniscot:Episode Reward = 266301218140.10153
# DEBUG:scse.controller.miniscot:Getting actions from Agent: renewables_firm.
# DEBUG:scse.modules.production.renewables_firm:renewables_firm produced 376033.06157441763 MW, sd 457817.00688592985
# DEBUG:scse.controller.miniscot:Getting actions from Agent: cheap_ramp_firm.
# DEBUG:scse.controller.miniscot:Getting actions from Agent: expensive_ramp_firm.
# DEBUG:scse.controller.miniscot:Getting actions from Agent: demand_generator.
# DEBUG:scse.controller.miniscot:clock: 399
# INFO:scse.controller.miniscot:timestep is = 399
# INFO:scse.controller.miniscot:datetime is = 2020-02-04 00:00:00
# INFO:scse.controller.miniscot:Timestep Reward = 668041322.4629767
# INFO:scse.controller.miniscot:Episode Reward = 266969259462.5645
# DEBUG:scse.controller.miniscot:Getting actions from Agent: renewables_firm.
# DEBUG:scse.modules.production.renewables_firm:renewables_firm produced 79204.92911161133 MW, sd 467197.6568837638
# DEBUG:scse.controller.miniscot:Getting actions from Agent: cheap_ramp_firm.
# DEBUG:scse.controller.miniscot:Getting actions from Agent: expensive_ramp_firm.
# DEBUG:scse.controller.miniscot:Getting actions from Agent: demand_generator.
# DEBUG:scse.controller.miniscot:clock: 400
# INFO:scse.controller.miniscot:timestep is = 400
# INFO:scse.controller.miniscot:datetime is = 2020-02-05 00:00:00
# INFO:scse.controller.miniscot:Timestep Reward = 656168197.1644645
# INFO:scse.controller.miniscot:Episode Reward = 267625427659.72897
# DEBUG:scse.controller.miniscot:Getting actions from Agent: renewables_firm.
# DEBUG:scse.modules.production.renewables_firm:renewables_firm produced 1096225.7848048955 MW, sd 481136.3363858968
# DEBUG:scse.controller.miniscot:Getting actions from Agent: cheap_ramp_firm.
# DEBUG:scse.controller.miniscot:Getting actions from Agent: expensive_ramp_firm.
# DEBUG:scse.controller.miniscot:Getting actions from Agent: demand_generator.
# DEBUG:scse.controller.miniscot:clock: 401
# INFO:scse.controller.miniscot:timestep is = 401
# INFO:scse.controller.miniscot:datetime is = 2020-02-06 00:00:00
# INFO:scse.controller.miniscot:Timestep Reward = 696849031.3921958
# INFO:scse.controller.miniscot:Episode Reward = 268322276691.12115
# DEBUG:scse.controller.miniscot:Getting actions from Agent: renewables_firm.
# DEBUG:scse.modules.production.renewables_firm:renewables_firm produced 766220.243972648 MW, sd 458598.789340222
# DEBUG:scse.controller.miniscot:Getting actions from Agent: cheap_ramp_firm.
# DEBUG:scse.controller.miniscot:Getting actions from Agent: expensive_ramp_firm.
# DEBUG:scse.controller.miniscot:Getting actions from Agent: demand_generator.
# DEBUG:scse.controller.miniscot:clock: 402
# INFO:scse.controller.miniscot:timestep is = 402
# INFO:scse.controller.miniscot:datetime is = 2020-02-07 00:00:00
# INFO:scse.controller.miniscot:Timestep Reward = 683648809.7589059
# INFO:scse.controller.miniscot:Episode Reward = 269005925500.88007
# DEBUG:scse.controller.miniscot:Getting actions from Agent: renewables_firm.
# DEBUG:scse.modules.production.renewables_firm:renewables_firm produced 1424057.4852768849 MW, sd 459314.24006629176
# DEBUG:scse.controller.miniscot:Getting actions from Agent: cheap_ramp_firm.
# DEBUG:scse.controller.miniscot:Getting actions from Agent: expensive_ramp_firm.
# DEBUG:scse.controller.miniscot:Getting actions from Agent: demand_generator.
# DEBUG:scse.controller.miniscot:clock: 403
# INFO:scse.controller.miniscot:timestep is = 403
# INFO:scse.controller.miniscot:datetime is = 2020-02-08 00:00:00
# INFO:scse.controller.miniscot:Timestep Reward = 709962299.4110754
# INFO:scse.controller.miniscot:Episode Reward = 269715887800.29114
# DEBUG:scse.controller.miniscot:Getting actions from Agent: renewables_firm.
# DEBUG:scse.modules.production.renewables_firm:renewables_firm produced 1169971.7943704345 MW, sd 457241.90503207635
# DEBUG:scse.controller.miniscot:Getting actions from Agent: cheap_ramp_firm.
# DEBUG:scse.controller.miniscot:Getting actions from Agent: expensive_ramp_firm.
# DEBUG:scse.controller.miniscot:Getting actions from Agent: demand_generator.
# DEBUG:scse.controller.miniscot:clock: 404
# INFO:scse.controller.miniscot:timestep is = 404
# INFO:scse.controller.miniscot:datetime is = 2020-02-09 00:00:00
# INFO:scse.controller.miniscot:Timestep Reward = 699798871.7748173
# INFO:scse.controller.miniscot:Episode Reward = 270415686672.06595
# DEBUG:scse.controller.miniscot:Getting actions from Agent: renewables_firm.
# DEBUG:scse.modules.production.renewables_firm:renewables_firm produced 558807.9974992821 MW, sd 458097.09750938497
# DEBUG:scse.controller.miniscot:Getting actions from Agent: cheap_ramp_firm.
# DEBUG:scse.controller.miniscot:Getting actions from Agent: expensive_ramp_firm.
# DEBUG:scse.controller.miniscot:Getting actions from Agent: demand_generator.
# DEBUG:scse.controller.miniscot:clock: 405
# INFO:scse.controller.miniscot:timestep is = 405
# INFO:scse.controller.miniscot:datetime is = 2020-02-10 00:00:00
# INFO:scse.controller.miniscot:Timestep Reward = 675352319.8999712
# INFO:scse.controller.miniscot:Episode Reward = 271091038991.9659
# DEBUG:scse.controller.miniscot:Getting actions from Agent: renewables_firm.
# DEBUG:scse.modules.production.renewables_firm:renewables_firm produced 689811.2057760392 MW, sd 461631.7923597117
# DEBUG:scse.controller.miniscot:Getting actions from Agent: cheap_ramp_firm.
# DEBUG:scse.controller.miniscot:Getting actions from Agent: expensive_ramp_firm.
# DEBUG:scse.controller.miniscot:Getting actions from Agent: demand_generator.
# DEBUG:scse.controller.miniscot:clock: 406
# INFO:scse.controller.miniscot:timestep is = 406
# INFO:scse.controller.miniscot:datetime is = 2020-02-11 00:00:00
# INFO:scse.controller.miniscot:Timestep Reward = 680592448.2310416
# INFO:scse.controller.miniscot:Episode Reward = 271771631440.19696
# DEBUG:scse.controller.miniscot:Getting actions from Agent: renewables_firm.
# DEBUG:scse.modules.production.renewables_firm:renewables_firm produced 1482769.5951321004 MW, sd 460467.8660854173
# DEBUG:scse.controller.miniscot:Getting actions from Agent: cheap_ramp_firm.
# DEBUG:scse.controller.miniscot:Getting actions from Agent: expensive_ramp_firm.
# DEBUG:scse.controller.miniscot:Getting actions from Agent: demand_generator.
# DEBUG:scse.controller.miniscot:clock: 407
# INFO:scse.controller.miniscot:timestep is = 407
# INFO:scse.controller.miniscot:datetime is = 2020-02-12 00:00:00
# INFO:scse.controller.miniscot:Timestep Reward = 660292022.460187
# INFO:scse.controller.miniscot:Episode Reward = 272431923462.65714
# DEBUG:scse.controller.miniscot:Getting actions from Agent: renewables_firm.
# DEBUG:scse.modules.production.renewables_firm:renewables_firm produced 1683165.7085934381 MW, sd 458329.22901467397
# DEBUG:scse.controller.miniscot:Getting actions from Agent: cheap_ramp_firm.
# DEBUG:scse.controller.miniscot:Getting actions from Agent: expensive_ramp_firm.
# DEBUG:scse.controller.miniscot:Getting actions from Agent: demand_generator.
# DEBUG:scse.controller.miniscot:clock: 408
# INFO:scse.controller.miniscot:timestep is = 408
# INFO:scse.controller.miniscot:datetime is = 2020-02-13 00:00:00
# INFO:scse.controller.miniscot:Timestep Reward = 629619199.1314377
# INFO:scse.controller.miniscot:Episode Reward = 273061542661.78857
# DEBUG:scse.controller.miniscot:Getting actions from Agent: renewables_firm.
# DEBUG:scse.modules.production.renewables_firm:renewables_firm produced 1336987.0150254702 MW, sd 459369.63323484047
# DEBUG:scse.controller.miniscot:Getting actions from Agent: cheap_ramp_firm.
# DEBUG:scse.controller.miniscot:Getting actions from Agent: expensive_ramp_firm.
# DEBUG:scse.controller.miniscot:Getting actions from Agent: demand_generator.
# DEBUG:scse.controller.miniscot:clock: 409
# INFO:scse.controller.miniscot:timestep is = 409
# INFO:scse.controller.miniscot:datetime is = 2020-02-14 00:00:00
# INFO:scse.controller.miniscot:Timestep Reward = 679838490.6792663
# INFO:scse.controller.miniscot:Episode Reward = 273741381152.46783
# DEBUG:scse.controller.miniscot:Getting actions from Agent: renewables_firm.
# DEBUG:scse.modules.production.renewables_firm:renewables_firm produced 419463.1422930891 MW, sd 458343.9286853434
# DEBUG:scse.controller.miniscot:Getting actions from Agent: cheap_ramp_firm.
# DEBUG:scse.controller.miniscot:Getting actions from Agent: expensive_ramp_firm.
# DEBUG:scse.controller.miniscot:Getting actions from Agent: demand_generator.
# DEBUG:scse.controller.miniscot:clock: 410
# INFO:scse.controller.miniscot:timestep is = 410
# INFO:scse.controller.miniscot:datetime is = 2020-02-15 00:00:00
# INFO:scse.controller.miniscot:Timestep Reward = 669778525.6917236
# INFO:scse.controller.miniscot:Episode Reward = 274411159678.15955
# DEBUG:scse.controller.miniscot:Getting actions from Agent: renewables_firm.
# DEBUG:scse.modules.production.renewables_firm:renewables_firm produced 994120.824766876 MW, sd 465318.99653624475
# DEBUG:scse.controller.miniscot:Getting actions from Agent: cheap_ramp_firm.
# DEBUG:scse.controller.miniscot:Getting actions from Agent: expensive_ramp_firm.
# DEBUG:scse.controller.miniscot:Getting actions from Agent: demand_generator.
# DEBUG:scse.controller.miniscot:clock: 411
# INFO:scse.controller.miniscot:timestep is = 411
# INFO:scse.controller.miniscot:datetime is = 2020-02-16 00:00:00
# INFO:scse.controller.miniscot:Timestep Reward = 658632800.5163586
# INFO:scse.controller.miniscot:Episode Reward = 275069792478.6759
# DEBUG:scse.controller.miniscot:Getting actions from Agent: renewables_firm.
# DEBUG:scse.modules.production.renewables_firm:renewables_firm produced 1121160.2152481745 MW, sd 458551.0052464179
# DEBUG:scse.controller.miniscot:Getting actions from Agent: cheap_ramp_firm.
# DEBUG:scse.controller.miniscot:Getting actions from Agent: expensive_ramp_firm.
# DEBUG:scse.controller.miniscot:Getting actions from Agent: demand_generator.
# DEBUG:scse.controller.miniscot:clock: 412
# INFO:scse.controller.miniscot:timestep is = 412
# INFO:scse.controller.miniscot:datetime is = 2020-02-17 00:00:00
# INFO:scse.controller.miniscot:Timestep Reward = 660360739.7021571
# INFO:scse.controller.miniscot:Episode Reward = 275730153218.37805
# DEBUG:scse.controller.miniscot:Getting actions from Agent: renewables_firm.
# DEBUG:scse.modules.production.renewables_firm:renewables_firm produced 694199.7317922027 MW, sd 457678.7761859549
# DEBUG:scse.controller.miniscot:Getting actions from Agent: cheap_ramp_firm.
# DEBUG:scse.controller.miniscot:Getting actions from Agent: expensive_ramp_firm.
# DEBUG:scse.controller.miniscot:Getting actions from Agent: demand_generator.
# DEBUG:scse.controller.miniscot:clock: 413
# INFO:scse.controller.miniscot:timestep is = 413
# INFO:scse.controller.miniscot:datetime is = 2020-02-18 00:00:00
# INFO:scse.controller.miniscot:Timestep Reward = 680767989.2716881
# INFO:scse.controller.miniscot:Episode Reward = 276410921207.6497
# DEBUG:scse.controller.miniscot:Getting actions from Agent: renewables_firm.
# DEBUG:scse.modules.production.renewables_firm:renewables_firm produced 1156363.9634070685 MW, sd 460411.83970861795
# DEBUG:scse.controller.miniscot:Getting actions from Agent: cheap_ramp_firm.
# DEBUG:scse.controller.miniscot:Getting actions from Agent: expensive_ramp_firm.
# DEBUG:scse.controller.miniscot:Getting actions from Agent: demand_generator.
# DEBUG:scse.controller.miniscot:clock: 414
# INFO:scse.controller.miniscot:timestep is = 414
# INFO:scse.controller.miniscot:datetime is = 2020-02-19 00:00:00
# INFO:scse.controller.miniscot:Timestep Reward = 699254558.5362828
# INFO:scse.controller.miniscot:Episode Reward = 277110175766.186
# DEBUG:scse.controller.miniscot:Getting actions from Agent: renewables_firm.
# DEBUG:scse.modules.production.renewables_firm:renewables_firm produced 1370333.4767896936 MW, sd 458396.0498196895
# DEBUG:scse.controller.miniscot:Getting actions from Agent: cheap_ramp_firm.
# DEBUG:scse.controller.miniscot:Getting actions from Agent: expensive_ramp_firm.
# DEBUG:scse.controller.miniscot:Getting actions from Agent: demand_generator.
# DEBUG:scse.controller.miniscot:clock: 415
# INFO:scse.controller.miniscot:timestep is = 415
# INFO:scse.controller.miniscot:datetime is = 2020-02-20 00:00:00
# INFO:scse.controller.miniscot:Timestep Reward = 707813339.0715877
# INFO:scse.controller.miniscot:Episode Reward = 277817989105.25757
# DEBUG:scse.controller.miniscot:Getting actions from Agent: renewables_firm.
# DEBUG:scse.modules.production.renewables_firm:renewables_firm produced 1495335.8267878834 MW, sd 458802.7203175001
# DEBUG:scse.controller.miniscot:Getting actions from Agent: cheap_ramp_firm.
# DEBUG:scse.controller.miniscot:Getting actions from Agent: expensive_ramp_firm.
# DEBUG:scse.controller.miniscot:Getting actions from Agent: demand_generator.
# DEBUG:scse.controller.miniscot:clock: 416
# INFO:scse.controller.miniscot:timestep is = 416
# INFO:scse.controller.miniscot:datetime is = 2020-02-21 00:00:00
# INFO:scse.controller.miniscot:Timestep Reward = 712813433.0715153
# INFO:scse.controller.miniscot:Episode Reward = 278530802538.3291
# DEBUG:scse.controller.miniscot:Getting actions from Agent: renewables_firm.
# DEBUG:scse.modules.production.renewables_firm:renewables_firm produced 1283917.9805789194 MW, sd 458608.7143440881
# DEBUG:scse.controller.miniscot:Getting actions from Agent: cheap_ramp_firm.
# DEBUG:scse.controller.miniscot:Getting actions from Agent: expensive_ramp_firm.
# DEBUG:scse.controller.miniscot:Getting actions from Agent: demand_generator.
# DEBUG:scse.controller.miniscot:clock: 417
# INFO:scse.controller.miniscot:timestep is = 417
# INFO:scse.controller.miniscot:datetime is = 2020-02-22 00:00:00
# INFO:scse.controller.miniscot:Timestep Reward = 704356719.2231568
# INFO:scse.controller.miniscot:Episode Reward = 279235159257.55225
# DEBUG:scse.controller.miniscot:Getting actions from Agent: renewables_firm.
# DEBUG:scse.modules.production.renewables_firm:renewables_firm produced 1202790.1927335882 MW, sd 457265.08214057446
# DEBUG:scse.controller.miniscot:Getting actions from Agent: cheap_ramp_firm.
# DEBUG:scse.controller.miniscot:Getting actions from Agent: expensive_ramp_firm.
# DEBUG:scse.controller.miniscot:Getting actions from Agent: demand_generator.
# DEBUG:scse.controller.miniscot:clock: 418
# INFO:scse.controller.miniscot:timestep is = 418
# INFO:scse.controller.miniscot:datetime is = 2020-02-23 00:00:00
# INFO:scse.controller.miniscot:Timestep Reward = 700814831.6777737
# INFO:scse.controller.miniscot:Episode Reward = 279935974089.23004
# DEBUG:scse.controller.miniscot:Getting actions from Agent: renewables_firm.
# DEBUG:scse.modules.production.renewables_firm:renewables_firm produced 1278451.470440258 MW, sd 458050.6907216748
# DEBUG:scse.controller.miniscot:Getting actions from Agent: cheap_ramp_firm.
# DEBUG:scse.controller.miniscot:Getting actions from Agent: expensive_ramp_firm.
# DEBUG:scse.controller.miniscot:Getting actions from Agent: demand_generator.
# DEBUG:scse.controller.miniscot:clock: 419
# INFO:scse.controller.miniscot:timestep is = 419
# INFO:scse.controller.miniscot:datetime is = 2020-02-24 00:00:00
# INFO:scse.controller.miniscot:Timestep Reward = 704138058.8176103
# INFO:scse.controller.miniscot:Episode Reward = 280640112148.04767
# DEBUG:scse.controller.miniscot:Getting actions from Agent: renewables_firm.
# DEBUG:scse.modules.production.renewables_firm:renewables_firm produced 2010427.9101832546 MW, sd 457730.99438049534
# DEBUG:scse.controller.miniscot:Getting actions from Agent: cheap_ramp_firm.
# DEBUG:scse.controller.miniscot:Getting actions from Agent: expensive_ramp_firm.
# DEBUG:scse.controller.miniscot:Getting actions from Agent: demand_generator.
# DEBUG:scse.controller.miniscot:clock: 420
# INFO:scse.controller.miniscot:timestep is = 420
# INFO:scse.controller.miniscot:datetime is = 2020-02-25 00:00:00
# INFO:scse.controller.miniscot:Timestep Reward = 681584829.3499377
