# %%
from scse.main import miniSCOTnotebook

# %%
m = miniSCOTnotebook()
# Out:
# DEBUG:scse.profiles.profile:Open profile file = /home/cperreault/scse1/lib/python3.7/site-packages/scse/profiles/newsvendor_demo_profile.json.
# DEBUG:scse.profiles.profile:module_name is scse.metrics.demo_newsvendor_cash_accounting
# DEBUG:scse.profiles.profile:module_name is scse.modules.selection.demo_newsvendor_selection
# DEBUG:scse.profiles.profile:module_name is scse.modules.topology.demo_newsvendor_network
# DEBUG:scse.profiles.profile:module_name is scse.modules.customer.demo_newsvendor_poisson_customer_order
# DEBUG:scse.profiles.profile:module_name is scse.modules.fulfillment.demo_newsvendor_closest_warehouse_fulfillment
# DEBUG:scse.profiles.profile:module_name is scse.modules.buying.demo_newsvendor_service_level_buying_policy
# DEBUG:scse.profiles.profile:module_name is scse.modules.vendor.demo_newsvendor_infinite_inventory
# DEBUG:scse.controller.miniscot:Getting context from Env: asin_list.
# ...

# %%
run_params = {
    
    'time_horizon':730
}

# %%
m.start(**run_params)
# Out:
# DEBUG:scse.profiles.profile:Open profile file = /home/cperreault/scse1/lib/python3.7/site-packages/scse/profiles/power_supply.json.
# DEBUG:scse.profiles.profile:module_name is scse.metrics.power_contract_profit
# DEBUG:scse.profiles.profile:module_name is scse.modules.production.renewables_firm
# DEBUG:matplotlib:matplotlib data path: /home/cperreault/scse1/lib/python3.7/site-packages/matplotlib/mpl-data
# DEBUG:matplotlib:CONFIGDIR=/home/cperreault/.config/matplotlib
# DEBUG:matplotlib:interactive is False
# DEBUG:matplotlib:platform is linux
# ...

# %%
import sys

# %%
sys.stdout = open('res.csv', 'w')

# %%
m.run()

# %%
m.start(**run_params)
# Out:
# DEBUG:scse.profiles.profile:Open profile file = /home/cperreault/scse1/lib/python3.7/site-packages/scse/profiles/power_supply.json.
# DEBUG:scse.profiles.profile:module_name is scse.metrics.power_contract_profit
# DEBUG:scse.profiles.profile:module_name is scse.modules.production.renewables_firm
# DEBUG:scse.profiles.profile:module_name is scse.modules.production.cheap_ramp_firm
# DEBUG:scse.profiles.profile:module_name is scse.modules.production.expensive_ramp_firm
# DEBUG:scse.profiles.profile:module_name is scse.modules.demand.power_demand
# INFO:GP:initializing Y
# INFO:GP:initializing inference method
# INFO:GP:adding kernel and likelihood as parameters
# DEBUG:scse.controller.miniscot:Resetting Agent: renewables_firm.
# DEBUG:scse.controller.miniscot:Resetting Agent: cheap_ramp_firm.
# DEBUG:scse.controller.miniscot:Resetting Agent: expensive_ramp_firm.
# DEBUG:scse.controller.miniscot:Resetting Agent: demand_generator.
# ...

# %%
m.run()
# Out:
# DEBUG:scse.controller.miniscot:Getting actions from Agent: renewables_firm.
# DEBUG:scse.modules.production.renewables_firm:Renewable firm produced [[15.77839173]] units of power with sd [0.83101306]
# DEBUG:scse.controller.miniscot:Getting actions from Agent: cheap_ramp_firm.
# DEBUG:scse.controller.miniscot:Getting actions from Agent: expensive_ramp_firm.
# DEBUG:scse.controller.miniscot:Getting actions from Agent: demand_generator.
# DEBUG:scse.modules.demand.power_demand:Market bought 222.3192747926893 (pred) + 3x8.851061653381436 (stddev) = 240.02139809945217 units of power
# DEBUG:scse.metrics.power_contract_profit:variance from renewables: 1.6620261180677323
# DEBUG:scse.metrics.power_contract_profit:15.778391732166558
# DEBUG:scse.metrics.power_contract_profit:quantity: 15.778391732166558, remaining demand: 225.90503248535333
# DEBUG:scse.metrics.power_contract_profit:21.0
# DEBUG:scse.metrics.power_contract_profit:quantity: 21.0, remaining demand: 204.90503248535333
# ...
