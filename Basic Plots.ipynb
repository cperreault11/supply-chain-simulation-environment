# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('out2.csv', names = ['total_cost', 'true_demand', 'demand_unc', 'renewable_var', 'renewable_prod'])

# %%
df['avg_cost'] = df['total_cost'] / df['true_demand']

# %%
print(df['avg_cost'].mean(), df['avg_cost'].var())
# Out:
# 69.12013174346326

# %%
plt.plot(df['renewable_prod'])

# %%
plt.plot(df['true_demand'])

# %%
plt.plot(df['avg_cost'])

# %%
plt.plot(df['renewable_var'])

# %%
df
# Out:
#        total_cost  true_demand  demand_unc  renewable_var  renewable_prod  \
# 0    17710.758635   238.080582    8.956305       3.717736       68.562687
# 1    13662.266990   225.131324    8.900866       3.716008      124.946597
# 2    14057.707275   216.092275    8.861387       3.823545      100.938921
# 3    15140.204377   204.592737    8.851836       3.729993       58.632586
# 4    13741.009888   185.727838    8.850564       3.716243       52.528116
# 5    13351.988243   182.913342    8.886762       3.720565       55.336180
# 6    12471.682875   198.605379    8.861929       3.717996      100.854902
# 7    15007.290484   202.235836    8.831939       3.729910       56.970784
# 8    17559.097331   224.043678    8.826437       3.716978       48.508651
# 9    16410.057676   228.495817    8.844097       3.726536       76.276901
# 10   17298.180152   233.652894    8.856311       3.718219       67.934316
# 11   14027.775956   212.906630    8.885416       3.715883       95.711955
# ...

# %%
ren100_1 = pd.read_csv('ren100_1.csv', names = ['total_cost', 'true_demand', 'demand_unc', 'renewable_var', 'renewable_prod'])
ren100_2 = pd.read_csv('ren100_2.csv', names = ['total_cost', 'true_demand', 'demand_unc', 'renewable_var', 'renewable_prod'])
ren100_3 = pd.read_csv('ren100_3.csv', names = ['total_cost', 'true_demand', 'demand_unc', 'renewable_var', 'renewable_prod'])
ren100_4 = pd.read_csv('ren100_4.csv', names = ['total_cost', 'true_demand', 'demand_unc', 'renewable_var', 'renewable_prod'])
ren100_5 = pd.read_csv('ren100_5.csv', names = ['total_cost', 'true_demand', 'demand_unc', 'renewable_var', 'renewable_prod'])

# %%
ren100_1['avg_cost'] = ren100_1['total_cost']/ren100_1['true_demand']
ren100_2['avg_cost'] = ren100_2['total_cost']/ren100_2['true_demand']
ren100_3['avg_cost'] = ren100_3['total_cost']/ren100_3['true_demand']
ren100_4['avg_cost'] = ren100_4['total_cost']/ren100_4['true_demand']
ren100_5['avg_cost'] = ren100_5['total_cost']/ren100_5['true_demand']

# %%
print(ren100_1['avg_cost'].mean(), ren100_1['avg_cost'].var())
print(ren100_2['avg_cost'].mean(), ren100_2['avg_cost'].var())
print(ren100_3['avg_cost'].mean(), ren100_3['avg_cost'].var())
print(ren100_4['avg_cost'].mean(), ren100_4['avg_cost'].var())
print(ren100_5['avg_cost'].mean(), ren100_5['avg_cost'].var())
# Out:
# 62.81382230390111 53.052130986107194
# 63.34864966057946 57.34880873815323
# 63.19050722890378 50.2242723212282
# 63.49715858498485 58.736384631719034
# 61.641720851945244 62.36153014852482

# %%
ren50_1 = pd.read_csv('ren50_1.csv', names = ['total_cost', 'true_demand', 'demand_unc', 'renewable_var', 'renewable_prod'])
ren50_2 = pd.read_csv('ren50_2.csv', names = ['total_cost', 'true_demand', 'demand_unc', 'renewable_var', 'renewable_prod'])
ren50_3 = pd.read_csv('ren50_3.csv', names = ['total_cost', 'true_demand', 'demand_unc', 'renewable_var', 'renewable_prod'])
ren50_4 = pd.read_csv('ren50_4.csv', names = ['total_cost', 'true_demand', 'demand_unc', 'renewable_var', 'renewable_prod'])
ren50_5 = pd.read_csv('ren50_5.csv', names = ['total_cost', 'true_demand', 'demand_unc', 'renewable_var', 'renewable_prod'])

# %%
ren50_1['avg_cost'] = ren50_1['total_cost']/ren50_1['true_demand']
ren50_2['avg_cost'] = ren50_2['total_cost']/ren50_2['true_demand']
ren50_3['avg_cost'] = ren50_3['total_cost']/ren50_3['true_demand']
ren50_4['avg_cost'] = ren50_4['total_cost']/ren50_4['true_demand']
ren50_5['avg_cost'] = ren50_5['total_cost']/ren50_5['true_demand']

# %%
print(ren50_1['avg_cost'].mean(), ren50_1['avg_cost'].var())
print(ren50_2['avg_cost'].mean(), ren50_2['avg_cost'].var())
print(ren50_3['avg_cost'].mean(), ren50_3['avg_cost'].var())
print(ren50_4['avg_cost'].mean(), ren50_4['avg_cost'].var())
print(ren50_5['avg_cost'].mean(), ren50_5['avg_cost'].var())
# Out:
# 75.14207479001162 15.819516764172635
# 75.1030362299652 15.995947007379604
# 74.77142693112071 20.689534422319845
# 75.15219451972139 16.662797199315378
# 75.55462036774752 21.678858108272863

# %%
ren200_1 = pd.read_csv('ren200_1.csv', names = ['total_cost', 'true_demand', 'demand_unc', 'renewable_var', 'renewable_prod'])
ren200_2 = pd.read_csv('ren200_2.csv', names = ['total_cost', 'true_demand', 'demand_unc', 'renewable_var', 'renewable_prod'])
ren200_3 = pd.read_csv('ren200_3.csv', names = ['total_cost', 'true_demand', 'demand_unc', 'renewable_var', 'renewable_prod'])
ren200_4 = pd.read_csv('ren200_4.csv', names = ['total_cost', 'true_demand', 'demand_unc', 'renewable_var', 'renewable_prod'])
ren200_5 = pd.read_csv('ren200_5.csv', names = ['total_cost', 'true_demand', 'demand_unc', 'renewable_var', 'renewable_prod'])

# %%
ren200_1['avg_cost'] = ren200_1['total_cost']/ren200_1['true_demand']
ren200_2['avg_cost'] = ren200_2['total_cost']/ren200_2['true_demand']
ren200_3['avg_cost'] = ren200_3['total_cost']/ren200_3['true_demand']
ren200_4['avg_cost'] = ren200_4['total_cost']/ren200_4['true_demand']
ren200_5['avg_cost'] = ren200_5['total_cost']/ren200_5['true_demand']

# %%
print(ren200_1['avg_cost'].mean(), ren200_1['avg_cost'].var())
print(ren200_2['avg_cost'].mean(), ren200_2['avg_cost'].var())
print(ren200_3['avg_cost'].mean(), ren200_3['avg_cost'].var())
print(ren200_4['avg_cost'].mean(), ren200_4['avg_cost'].var())
print(ren200_5['avg_cost'].mean(), ren200_5['avg_cost'].var())
# Out:
# 48.61706810007037 38.293332006321535
# 48.27051937910109 29.29339655075539
# 48.02692631576069 31.060225178340303
# 48.00433683597375 34.549807205422745
# 47.88486108023329 28.708855467340594

# %%
ren200_1
# Out:
#        total_cost  true_demand  demand_unc  renewable_var  renewable_prod  \
# 0     9243.459164   206.037775    8.885861       5.255586      199.662955
# 1    10458.991280   201.718451    8.843761       5.260088      149.073821
# 2    12889.841949   206.640743    8.844947       5.258914      109.673680
# 3    16897.030191   223.141057    8.846195       5.346650       59.923622
# 4     9109.013213   197.529074    8.872883       5.850009      169.507404
# 5     8828.470937   190.917249    8.884676       5.254468      162.188526
# 6    12197.134896   224.405466    8.861854       5.254675      155.334622
# 7    12960.419976   215.771086    8.862425       5.256117      124.707654
# 8     9558.988819   213.903270    8.835148       5.293383      206.208447
# 9    11977.545563   226.001190    8.831771       5.261730      162.458463
# 10   11526.566393   234.723833    8.851039       5.254646      187.108252
# 11   10080.015807   226.148518    8.889159       5.257107      210.902324
# ...

# %%
# also, if we compare more directly to natural gas instead of coal, might start to see more of the effect of
# of increased need for backup
plt.plot(ren100_1['renewable_prod'])

# also just a note that these sims above are all 730 days, flex_cap = 50, static_cap = 200, variable_cap is changed
